# %% [markdown]
# # Problem Set 4: Networks

# %% [markdown]
# In this problem set we are going to be working with network-like data. We will be using a smaller dataset obtained from foursquare's API in Riyadh. The dataset was constructed by scrapping an API endpoint that given a venue, it lists the next top 5 venues where users usually check-in afterwards. All the data is aggregated, and the specifics of each trip, or check-in sequence are not available. However, it can provide a good overview of some general dynamics around the city.
#
# In the dataset, every node of venue, is connected to at least other node or venue. More popular nodes will be connected to more nodes, or will have more edges attached to them. Additionally, by constructing a network with the data, we can analyze some other interesting properties that might give us some insights of the urban dynamics of the region.
#
# 1. Constructing a network with the dataset.
# 2. Assigning spatial properties to the network.
# 3. Analyzing some basic network properties.
# 4. Constructing exploratory visualizations that help us make sense out of our analysis and dataset.

# %%
# Import some libraries
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# This allows plots to appear on the IPython notebook.
# %matplotlib inline

# %% [markdown]
# The data is contained in two different `CSV` files: `FoursqureLinksNetwork.csv` and `FoursqureCheckinNodes.csv`. First, we will import the CSV containing all the edges among **Foursquare** venues, and construct a `networkx` network. In this case, the node index or name will be the venue ID.

# %%
# Use pandas to import the csv
df_edges = pd.read_csv('data/FoursqureLinksNetwork.csv', sep=",")
df_edges.head()
# Out:
#                     FROM-ID                     TO-ID  DISTANCE
# 0  4f3381cae4b0befff0254890  4d90bb7ffa9437048ca338c6  0.050111
# 1  4f3381cae4b0befff0254890  50e4021b582f294b85631919  0.083781
# 2  4f3381cae4b0befff0254890  4e341a00e4cdf7a42cad9421  0.046179
# 3  4f3381cae4b0befff0254890  50433012e4b05698baa75339  0.057012
# 4  4f3381cae4b0befff0254890  4f8f03f5e4b09b4d92853b2c  0.029747

# %% [markdown]
# Next, we will import the CSV containing all the nodes representing **Foursquare** venues.

# %%
df_nodes = pd.read_csv('data/FoursqureCheckinNodes.csv', sep=",")
df_nodes.head()
# Out:
#                          ID  \
# 0  558e5ce5498e164a5cb27afc
# 1  4ccd23f1c0378cfa93b68b48
# 2  4da5ec8a4b2280544b678da0
# 3  50295233e4b0db2acbb75c69
# 4  4da5ec8a4b2280544b678da0
#
#                                                 NAME  \
# 0  �����_�� �_�������� ���_���� - King Khalid Air...
# 1                           Princess Nora University
# 2   Lulu Hypermarket | �������� ���_�_�������_������
# 3                        Papparoti | ���_���_�����ș_
# 4                                        Avenue Mall
#
#                     CATEGORY  CHECK-IN        LAT       LONG
# 0           Airport Terminal        21  24.760483  46.705338
# 1  College Academic Building       532  24.774344  46.728845
# 2           Department Store      6453  24.663989  46.703757
# 3                Coffee Shop      2168  24.693468  46.669636
# 4           Department Store      1474  24.663569  46.703937

# %% [markdown]
# ## Part 1
#
# Now, using your recently acquired **Pandas** knowledge, use **Pandas'** `.join` or `.merge` functions, to match the index of the origin id with its latitude and longitude (we want to add new columns with the lat and lon values for a given node). Create a new dataframe with the df_edge (including from-id, to-id, and distance columns) and add a **lat_to and lon_to** column to the datafram containing this information. Do the same with the destination id, but name the respective columns **lat_from and lon_from**.
#
# **Deliverable**
# * A pandas Dataframe with 4 new columns: the columns should correspond to the lat and lon of the **FROM-ID** and **TO-ID** columns.

# %%
# Your Code here

df_edges = pd.merge(df_edges, df_nodes[['ID', 'LAT','LONG']], left_on = 'FROM-ID', right_on = 'ID')
df_edges.rename(columns={'LAT': 'LAT_from', 'LONG': 'LONG_from'}, inplace=True)

df_edges = pd.merge(df_edges, df_nodes[['ID', 'LAT','LONG']], left_on = 'TO-ID', right_on = 'ID')
df_edges.rename(columns={'LAT': 'LAT_to', 'LONG': 'LONG_to'}, inplace=True)

df_edges.drop(['ID_x', 'ID_y'], axis=1, inplace=True)

df_edges.head()
# Out:
#                     FROM-ID                     TO-ID  DISTANCE   LAT_from  \
# 0  50295233e4b0db2acbb75c69  4f1d62b0e4b03543a3409cd2  0.129974  24.693468
# 1  4fcf729ae4b07997d3141487  4f1d62b0e4b03543a3409cd2  0.017338  24.692186
# 2  4fcf729ae4b07997d3141487  4f1d62b0e4b03543a3409cd2  0.017338  24.692337
# 3  5318e95f498eaff004e39f6c  533687b3498ec0c5b90ff33b  0.030966  24.691785
# 4  5318e95f498eaff004e39f6c  533687b3498ec0c5b90ff33b  0.030966  24.691748
#
#    LONG_from     LAT_to    LONG_to
# 0  46.669636  24.691873  46.668853
# 1  46.670004  24.691873  46.668853
# 2  46.669961  24.691873  46.668853
# 3  46.669735  24.691514  46.669664
# 4  46.669056  24.691514  46.669664

# %% [markdown]
# ## Part 2
#
# Now, that we have an appropriate data structure, we will be creating a `networkx` network.

# %%
# Let's define an empty undirected graph.
RG = nx.Graph()

# %% [markdown]
# Now let's use the `df_nodes` to add nodes to our newly created graph. The node index or name will be the **ID** column of the dataframe. Make sure to add the rest of the dataframe columns to the node as properties.
#
# `Hint: You can loop through all the rows, and use each one of their values to add a node and define specific properties. The property name should be the same as the column name.`
#
# **Deliverable**
# * You should populate the **RG** network with all the nodes part of the `df_nodes` dataframe. All the nodes should also have the additional columns as a node property. To show that you correctly populated the network, print out the **node names**, and the **number of nodes**.

# %%
# Add nodes to the graph here

keys = ['ID', 'NAME', 'CATEGORY', 'CHECK-IN', 'LAT', 'LONG']

for row in df_nodes.itertuples(index=False):
    values = row[:]
    
    node_attributes = dict(zip(keys, values))
    
    RG.add_node(row[0], attr_dict=node_attributes, pos=(row[4], row[5]))

print 'Number of nodes: ' + str(RG.number_of_nodes())

for node in RG:
    print 'node name: ' + node
# Out:
# Number of nodes: 275
# node name: 5193a1ad498eb76c92f3fb9d
# node name: 51081ee0e4b093dcac39e0ec
# node name: 547e1a04498e3f5770351032
# node name: 4c84299051ada1cdb8ca2c10
# node name: 54441e14498ec84e43188646
# node name: 4ea9bbd302d52c460a8980d5
# node name: 530b9841498e9d01f354d57c
# node name: 4eff5130b8f787cad09ace8d
# node name: 4f561bcae4b0d0433013e4ee
# node name: 4d2146a4d7b0b1f77cf71b9f
# node name: 4d98c87b744f3704d7dff757
# node name: 5257253411d294223f9f3688
# node name: 533687b3498ec0c5b90ff33b
# node name: 4f3a9c99e4b0928989480081
# node name: 4f1d62b0e4b03543a3409cd2
# node name: 4db3038a43a1369cb5989f18
# node name: 50b08d04e4b045752b6cda32
# node name: 4efef727490182a1a6d3887b
# node name: 4b9948a2f964a520097035e3
# node name: 4e7c9e0a88777c30772abe29
# node name: 4d4be007f523a143698f6f9d
# node name: 4b781727f964a52058b52ee3
# node name: 50ddf988e4b0a2f2fe7b2a37
# node name: 52c44ed2498e2ff9cc1d2355
# node name: 4f817c97e4b0c7b85619c02f
# node name: 4b897856f964a520503932e3
# node name: 4ff80f35e4b058e1656d0444
# node name: 52effe1e498e631c290b8416
# node name: 4f6cadffe4b032eb625233d5
# node name: 4b7c4529f964a5209f882fe3
# node name: 4c3f278f51dee21ed792eb6e
# node name: 5197bf24498ec577cf5bb723
# node name: 5318e95f498eaff004e39f6c
# node name: 536b5ae7498e047e33524612
# node name: 5392bba3498ee0e5e0b5258f
# node name: 4eee25c57ee5f4538830f7e2
# node name: 4e91596e49013919db2fba98
# node name: 4ead94b0dab4a75e0a2724a8
# node name: 4dc56d65e4cd169dc64be1b0
# node name: 51120d23e4b0fe8b7a8d994b
# node name: 4f713ceee4b022ab214c0915
# node name: 54b4275b498e143afedbd2ce
# node name: 4c4c19985609c9b6dbac0992
# node name: 52c43f83498e0450ea105486
# node name: 54a97aa3498e1d3830c722a6
# node name: 4d4c01cfe4fd6ea8f7e8be61
# node name: 4f3d6f66e4b0e602915a447c
# node name: 4ea2f07e722ec75ade815508
# node name: 520d511711d2b31f9d7727b0
# node name: 522b709511d203fd862ad7aa
# node name: 541ff49b498e451a8f1a7164
# node name: 4bcc31a7b6c49c74e64b9391
# node name: 4cc3237ab2beb1f7d99e144c
# node name: 53495b96498e2db72f1394ed
# node name: 4dee531fe4cd032b189f9735
# node name: 4b7fff0bf964a520924930e3
# node name: 50716385e4b0559b4dbfcd84
# node name: 4eaac9cecc217eb08e78c735
# node name: 4f510a56e4b0390b959de7ab
# node name: 5043b34ee4b02607d16e1bd0
# node name: 4d1335a5d0fda093324eb157
# node name: 4c9b53239c663704381060fd
# node name: 5298688b498ecb8271e30ab9
# node name: 4f2aac55e4b04e33baa7e9ca
# node name: 4e88ab018b81affddc4d1f91
# node name: 560a6995498e3c55b65fd97f
# node name: 51e84d06498ea35b580546b1
# node name: 4b78de8df964a52018e52ee3
# node name: 51f4590b498e369ef2e4fd00
# node name: 51865d865019e19c41709a6b
# node name: 4f7d67cbe4b07b0956ff365c
# node name: 5187a8c1498ea7ade1f0fea5
# node name: 4e8db67782319c780c61818b
# node name: 4e973ca4722eef174f72d523
# node name: 536e07f8498ee2f0d56d8f91
# node name: 4b713499f964a5207c3c2de3
# node name: 4dcaa1351f6e2812677b47b1
# node name: 4f08a3e6e4b0540ca2543782
# node name: 53bc7155498e75461da91ef5
# node name: 4f8dfd2ce4b0cb22872a2bf3
# node name: 50013226e4b025b2580c51aa
# node name: 51829721498ef3589c3c04a5
# node name: 543434a0498e92eb4a7edc7e
# node name: 4db1535243a1bea42bc84163
# node name: 4f78ad95e4b00562b70989fa
# node name: 546f3643498e7269b251c2c9
# node name: 5356a705498e70d06fc1a884
# node name: 512643bce4b0f48095f51257
# node name: 519e2a43498e352a6e5be4de
# node name: 4faa3bfbe4b0dc75ba1f75f0
# node name: 4b71035af964a52053372de3
# node name: 4eb6ffc530f8d0f18d0507bf
# node name: 54cce87a498e1f968efc1e8d
# node name: 554be02c498e01d1a1f779b6
# node name: 4f128e66e4b0044a2469424f
# node name: 4c192a06d4d9c928c28df029
# node name: 5049e167e4b0568d3c3d5d5d
# node name: 4f4bd898e4b0927adc54c536
# node name: 508ed42fe4b0c36e94d12fde
# node name: 4e060d497d8b2a018051a4fc
# node name: 553019f9498ef7e26706245c
# node name: 4fae7373e4b08a2bb957d118
# node name: 4ea674069a524accd190a45d
# node name: 561920ab498e0c5c48df227d
# node name: 4b65bb89f964a52059fc2ae3
# node name: 51b22ffa498eec8aca67b1d4
# node name: 5203e924498e3cff7919c1fc
# node name: 4c01291ccf3aa5935b88ccb0
# node name: 50583de6e4b02ba603de9f2e
# node name: 50d5f40ae4b0a7a64fba7fa8
# node name: 55f5a11e498e0e311c40c623
# node name: 4cc9bc93d338236a9c6ba47c
# node name: 50ae0262e4b042e77fd721ab
# node name: 53944553498ecef1831affe3
# node name: 4dbd47e20cb691071cb6454a
# node name: 4f2ad24ae4b050ce91a076f1
# node name: 4bbf8fdb74a9a593c6aacef6
# node name: 5229e9e6498e14e4533bca01
# node name: 54a2adb4498e1c9f0f01199b
# node name: 4db96e3c6e818f67a9be43d6
# node name: 5273c53111d2ec099a13fe9a
# node name: 4f6f2e3be4b0e3b3be8a7752
# node name: 52851cc711d28cd203abc725
# node name: 4b914064f964a5204fad33e3
# node name: 56004cce498ecbc155414db6
# node name: 4d04b06554d0236a6594f0d5
# node name: 5380ed0c498eaf0c7902f1d3
# node name: 5012fb8de4b0f8ec77f1da9d
# node name: 523da4e6498e38c1d0200689
# node name: 51929f90498e72002b46a05a
# node name: 4f8dfe66e4b0036b6ebffec4
# node name: 4ee0b8af93ad1adedc126bde
# node name: 4c8fbb1e0b9e3704ddce615e
# node name: 4dd69987b0fb8af38070e940
# node name: 4ea56ab7b80355a982f8cfa3
# node name: 557eec98498e12f1467e576c
# node name: 54b82104498ed2e15d56349d
# node name: 52a8b7fb11d2292923a38c7d
# node name: 4e2021be18a88345f03cd013
# node name: 51462363e4b0634beae34f19
# node name: 54f48dd8498e5a79cca0d7e5
# node name: 4ff58b5ae4b038644a9a08be
# node name: 4be80229ee96c9280e86fdbf
# node name: 4b8d3a23f964a52088ee32e3
# node name: 4be84fce88ed2d7f9bb7cb1d
# node name: 4b72bbd3f964a52006862de3
# node name: 4e99dbdfbe7bc875aa42960b
# node name: 4ce06c1b7e2e236afc128b1b
# node name: 4bc223d074a9a59359d2d2f6
# node name: 4da5ec8a4b2280544b678da0
# node name: 51756c70e4b0182f6ca786f4
# node name: 504c55e7e4b04421f3310d34
# node name: 4f69ee04e4b0656e874897dd
# node name: 4b838dfcf964a520950931e3
# node name: 512e4182e4b05f7d4843766f
# node name: 51ac6c98498e44427112f9bf
# node name: 5155aaffe4b0ea6b60f6a57a
# node name: 4f15c269e4b03f4c03fb50e0
# node name: 4f6de0dae4b01489ba002603
# node name: 4f1a96f2e4b08fa663deae89
# node name: 4eeb82628b814fef89abbc58
# node name: 4ed663742c5b3d826ea3dd7d
# node name: 4bc2c6b374a9a593fbbcd3f6
# node name: 55a8199d498e61367d215ad2
# node name: 4d64bf0bb470a14331741dfe
# node name: 4b6afa55f964a5202fea2be3
# node name: 5229a4d38bbd9e033d6ef618
# node name: 511808e6e4b0d096b601a12a
# node name: 521659d211d2f12183364adf
# node name: 4f47ce0be4b0c8395ee2c605
# node name: 4c4be510712ac9284c068a6d
# node name: 4d6fe31c0187236a34ada2ba
# node name: 4cd190ef7b685481edc9c7f8
# node name: 555f6da2498eb806fd973388
# node name: 4dc2ea4afa7608e86fe52b0d
# node name: 531e16bd498efd001f4e1e60
# node name: 4fcf729ae4b07997d3141487
# node name: 53aea9b6498e1da25de38ae2
# node name: 4bcc8fa2b6c49c7455f09391
# node name: 4ccd23f1c0378cfa93b68b48
# node name: 507c6210e4b076bc192f1072
# node name: 4f252b1be4b006e5c2e68f30
# node name: 4cb86ba69552b60cd855cc8b
# node name: 55c3580e498e110cb64902ed
# node name: 55a923d5498e3f6acc563a51
# node name: 548ae2fb498e928ab65ea574
# node name: 52151be511d28592d8410438
# node name: 5318cc05498e56c34b1ff045
# node name: 510a9299e4b0de3a2a1b168c
# node name: 4f6b3475e4b0b949c4bff64e
# node name: 4cab502436fa6dcbd0e5d778
# node name: 4bb78b8f3db7b7139222209a
# node name: 4ed06c63b8f7971d6aaff4b6
# node name: 4c0e96c1c6cf76b028fb8051
# node name: 55d63d73498eeae64dff98b8
# node name: 4ea3a50430f8b9d5acdf2dfb
# node name: 4e88b75429c2ea60eefec400
# node name: 4b82e734f964a52022ec30e3
# node name: 4bcf4b08b221c9b61dc0d1d0
# node name: 4f41391be4b0f7b459efed08
# node name: 50ffb51fe4b0a49395f7f300
# node name: 50295233e4b0db2acbb75c69
# node name: 502d7916e4b0648636b82c30
# node name: 4ecfd1a06c2510ace0371373
# node name: 558e5ce5498e164a5cb27afc
# node name: 4f05abfab8f7dcbb400bac99
# node name: 50b10a19e4b004e6d2ec4344
# node name: 5042691be4b055ecd356a70e
# node name: 4d8b488cbc848cfacb8bec2b
# node name: 4d629fbd865a224b9119c485
# node name: 4e844af9d3e35a80a8e7ac53
# node name: 4c601b8490b2c9b6d7013c22
# node name: 553a0ac0498e07485ab6eb39
# node name: 4f3566dde4b0d605a55343aa
# node name: 4c2378557e85c9283495bd21
# node name: 4f82f949e4b0c7b857825375
# node name: 509699e9e4b0e52fa47b9ed0
# node name: 4c798fc193ef236aa517b00f
# node name: 4f1eb45ee4b0293a86501bdc
# node name: 4c4c53dbc668e21ee8525afb
# node name: 4d6174ab73e76a311d0ce196
# node name: 4fd073eae4b03518ead765e2
# node name: 526bc398498edc288cd3af17
# node name: 520533d411d28fa52eae759b
# node name: 50e1f196e4b0748c84074466
# node name: 4d9d743a83f36ea82234b894
# node name: 4e8ab3a3b803fd0aa06a131e
# node name: 52efd23b11d2203926fb13d2
# node name: 54d9b9fa498ea38f91e08406
# node name: 53b710ef498e3c01b54e7248
# node name: 4c2c9f6ab34ad13aba8cebce
# node name: 4f0c62ade4b0065899e607da
# node name: 4efdab659a520dfd643bd750
# node name: 53de1388498e478b059e1d7d
# node name: 4e5aba9a1f6e804280d74be3
# node name: 4cebe55ce1eeb60c48dbb5ae
# node name: 50ae9bdce4b03c6b1d2395ff
# node name: 4cf925a14464b60ca97964f8
# node name: 52c11e7a11d21c6e7f7c0e7b
# node name: 4e779471d22d80eb34249414
# node name: 51b22cd0498ef72ef8df784c
# node name: 4e663c9c7d8b85408b4502ca
# node name: 5540d43b498eccfc106a61f6
# node name: 4bea77e6a9900f47f3841640
# node name: 54bd3160498e8cea0236caff
# node name: 4c892e4897828cfa5630a2aa
# node name: 4d1de1b8dd6a236a44642138
# node name: 4be70e16cf200f47b634153c
# node name: 4ba6f421f964a5209f7939e3
# node name: 4ba24acef964a52067ea37e3
# node name: 506f16bfe4b0eefb57fca019
# node name: 4ff8433ee4b002d4d3d4992c
# node name: 514a25f2e4b0b12bdd3b4f96
# node name: 54b01117498e18b8bcee3f74
# node name: 4f4a7820e4b07165fb4b3bcb
# node name: 51816e24498e208c8ca3f1bd
# node name: 4e6a5492a809290267f633c6
# node name: 4f58742ae4b0e48a878ebeb7
# node name: 4eb81e4661af0dda917c47ae
# node name: 4e7b3595dab41c8304c23e3e
# node name: 4ead7c5f02d5cf33fa6f9014
# node name: 4ecbd1a093adb4bd1b56c555
# node name: 4ec2ba5c775b802d1ff48dbf
# node name: 51d3194d498ef335e1bdc07f
# node name: 4e5bcac318388cd5cbc1a9c5
# node name: 4f744674e4b026e79186b5e4
# node name: 516df5b9f31cd0ea72e739cb
# node name: 51e06a2b498ed38b41183bea
# node name: 54cb6228498ed74155aa6871
# node name: 54c90c91498e622b8b8e2e70
# node name: 5106827fe4b0ad7f444202ad
# node name: 4b8f57b6f964a520025233e3
# node name: 555c9aa6498e86f0d8a20e2d
# node name: 4ff3f389e4b05ae522acd704
# node name: 5139fc8ae4b004aa50c9d237

# %% [markdown]
# Now let's use the new joined dataframe you just made in part 1, to add edges to our graph. The edge index is the **Row Number** of the dataframe. Make sure to add the rest of the dataframe columns to the node as properties (such as lat_from, lon_from, lat_to, and lon_to).
#
# `Hint: You can loop through all the rows of the dataframe, and use each one of edge to and from ID values to add an edge and define specific properties. The property name should be the same as the column name.`
#
# ```Python
# # To add properties to a node you can simply do:
# G.add_node(node_id, node_property_n="this node's property N")
# ```
#
# **Deliverable**
# * You should populate the **RG** network with all the edges part of the `df_edges` dataframe. All the edges should also have the additional columns as a node property (in this case just the distance column). To show that you correctly populated the network, print out the **edges**, and the **number of edges**.

# %%
# Add edges to the graph here

keys = ['DISTANCE', 'LAT_from', 'LONG_from', 'LAT_to', 'LONG_to']

for row in df_edges.itertuples(index=False):
    
    values = row[:2]
    
    edge_attributes = dict(zip(keys, values))
    
    RG.add_edge(row[0], row[1], attr_dict=edge_attributes)
       
print 'Number of edges: ' + str(RG.number_of_edges())

for edge in RG:
    print 'edge name: ' + edge
# Out:
# Number of edges: 139
# edge name: 5193a1ad498eb76c92f3fb9d
# edge name: 51081ee0e4b093dcac39e0ec
# edge name: 547e1a04498e3f5770351032
# edge name: 4c84299051ada1cdb8ca2c10
# edge name: 54441e14498ec84e43188646
# edge name: 4ea9bbd302d52c460a8980d5
# edge name: 530b9841498e9d01f354d57c
# edge name: 4eff5130b8f787cad09ace8d
# edge name: 4f561bcae4b0d0433013e4ee
# edge name: 4d2146a4d7b0b1f77cf71b9f
# edge name: 4d98c87b744f3704d7dff757
# edge name: 5257253411d294223f9f3688
# edge name: 533687b3498ec0c5b90ff33b
# edge name: 4f3a9c99e4b0928989480081
# edge name: 4f1d62b0e4b03543a3409cd2
# edge name: 4db3038a43a1369cb5989f18
# edge name: 50b08d04e4b045752b6cda32
# edge name: 4efef727490182a1a6d3887b
# edge name: 4b9948a2f964a520097035e3
# edge name: 4e7c9e0a88777c30772abe29
# edge name: 4d4be007f523a143698f6f9d
# edge name: 4b781727f964a52058b52ee3
# edge name: 50ddf988e4b0a2f2fe7b2a37
# edge name: 52c44ed2498e2ff9cc1d2355
# edge name: 4f817c97e4b0c7b85619c02f
# edge name: 4b897856f964a520503932e3
# edge name: 4ff80f35e4b058e1656d0444
# edge name: 52effe1e498e631c290b8416
# edge name: 4f6cadffe4b032eb625233d5
# edge name: 4b7c4529f964a5209f882fe3
# edge name: 4c3f278f51dee21ed792eb6e
# edge name: 5197bf24498ec577cf5bb723
# edge name: 5318e95f498eaff004e39f6c
# edge name: 536b5ae7498e047e33524612
# edge name: 5392bba3498ee0e5e0b5258f
# edge name: 4eee25c57ee5f4538830f7e2
# edge name: 4e91596e49013919db2fba98
# edge name: 4ead94b0dab4a75e0a2724a8
# edge name: 4dc56d65e4cd169dc64be1b0
# edge name: 51120d23e4b0fe8b7a8d994b
# edge name: 4f713ceee4b022ab214c0915
# edge name: 54b4275b498e143afedbd2ce
# edge name: 4c4c19985609c9b6dbac0992
# edge name: 52c43f83498e0450ea105486
# edge name: 54a97aa3498e1d3830c722a6
# edge name: 4d4c01cfe4fd6ea8f7e8be61
# edge name: 4f3d6f66e4b0e602915a447c
# edge name: 4ea2f07e722ec75ade815508
# edge name: 520d511711d2b31f9d7727b0
# edge name: 522b709511d203fd862ad7aa
# edge name: 541ff49b498e451a8f1a7164
# edge name: 4bcc31a7b6c49c74e64b9391
# edge name: 4cc3237ab2beb1f7d99e144c
# edge name: 53495b96498e2db72f1394ed
# edge name: 4dee531fe4cd032b189f9735
# edge name: 4b7fff0bf964a520924930e3
# edge name: 50716385e4b0559b4dbfcd84
# edge name: 4eaac9cecc217eb08e78c735
# edge name: 4f510a56e4b0390b959de7ab
# edge name: 5043b34ee4b02607d16e1bd0
# edge name: 4d1335a5d0fda093324eb157
# edge name: 4c9b53239c663704381060fd
# edge name: 5298688b498ecb8271e30ab9
# edge name: 4f2aac55e4b04e33baa7e9ca
# edge name: 4e88ab018b81affddc4d1f91
# edge name: 560a6995498e3c55b65fd97f
# edge name: 51e84d06498ea35b580546b1
# edge name: 4b78de8df964a52018e52ee3
# edge name: 51f4590b498e369ef2e4fd00
# edge name: 51865d865019e19c41709a6b
# edge name: 4f7d67cbe4b07b0956ff365c
# edge name: 5187a8c1498ea7ade1f0fea5
# edge name: 4e8db67782319c780c61818b
# edge name: 4e973ca4722eef174f72d523
# edge name: 536e07f8498ee2f0d56d8f91
# edge name: 4b713499f964a5207c3c2de3
# edge name: 4dcaa1351f6e2812677b47b1
# edge name: 4f08a3e6e4b0540ca2543782
# edge name: 53bc7155498e75461da91ef5
# edge name: 4f8dfd2ce4b0cb22872a2bf3
# edge name: 50013226e4b025b2580c51aa
# edge name: 51829721498ef3589c3c04a5
# edge name: 543434a0498e92eb4a7edc7e
# edge name: 4db1535243a1bea42bc84163
# edge name: 4f78ad95e4b00562b70989fa
# edge name: 546f3643498e7269b251c2c9
# edge name: 5356a705498e70d06fc1a884
# edge name: 512643bce4b0f48095f51257
# edge name: 519e2a43498e352a6e5be4de
# edge name: 4faa3bfbe4b0dc75ba1f75f0
# edge name: 4b71035af964a52053372de3
# edge name: 4eb6ffc530f8d0f18d0507bf
# edge name: 54cce87a498e1f968efc1e8d
# edge name: 554be02c498e01d1a1f779b6
# edge name: 4f128e66e4b0044a2469424f
# edge name: 4c192a06d4d9c928c28df029
# edge name: 5049e167e4b0568d3c3d5d5d
# edge name: 4f4bd898e4b0927adc54c536
# edge name: 508ed42fe4b0c36e94d12fde
# edge name: 4e060d497d8b2a018051a4fc
# edge name: 553019f9498ef7e26706245c
# edge name: 4fae7373e4b08a2bb957d118
# edge name: 4ea674069a524accd190a45d
# edge name: 561920ab498e0c5c48df227d
# edge name: 4b65bb89f964a52059fc2ae3
# edge name: 51b22ffa498eec8aca67b1d4
# edge name: 5203e924498e3cff7919c1fc
# edge name: 4c01291ccf3aa5935b88ccb0
# edge name: 50583de6e4b02ba603de9f2e
# edge name: 50d5f40ae4b0a7a64fba7fa8
# edge name: 55f5a11e498e0e311c40c623
# edge name: 4cc9bc93d338236a9c6ba47c
# edge name: 50ae0262e4b042e77fd721ab
# edge name: 53944553498ecef1831affe3
# edge name: 4dbd47e20cb691071cb6454a
# edge name: 4f2ad24ae4b050ce91a076f1
# edge name: 4bbf8fdb74a9a593c6aacef6
# edge name: 5229e9e6498e14e4533bca01
# edge name: 54a2adb4498e1c9f0f01199b
# edge name: 4db96e3c6e818f67a9be43d6
# edge name: 5273c53111d2ec099a13fe9a
# edge name: 4f6f2e3be4b0e3b3be8a7752
# edge name: 52851cc711d28cd203abc725
# edge name: 4b914064f964a5204fad33e3
# edge name: 56004cce498ecbc155414db6
# edge name: 4d04b06554d0236a6594f0d5
# edge name: 5380ed0c498eaf0c7902f1d3
# edge name: 5012fb8de4b0f8ec77f1da9d
# edge name: 523da4e6498e38c1d0200689
# edge name: 51929f90498e72002b46a05a
# edge name: 4f8dfe66e4b0036b6ebffec4
# edge name: 4ee0b8af93ad1adedc126bde
# edge name: 4c8fbb1e0b9e3704ddce615e
# edge name: 4dd69987b0fb8af38070e940
# edge name: 4ea56ab7b80355a982f8cfa3
# edge name: 557eec98498e12f1467e576c
# edge name: 54b82104498ed2e15d56349d
# edge name: 52a8b7fb11d2292923a38c7d
# edge name: 4e2021be18a88345f03cd013
# edge name: 51462363e4b0634beae34f19
# edge name: 54f48dd8498e5a79cca0d7e5
# edge name: 4ff58b5ae4b038644a9a08be
# edge name: 4be80229ee96c9280e86fdbf
# edge name: 4b8d3a23f964a52088ee32e3
# edge name: 4be84fce88ed2d7f9bb7cb1d
# edge name: 4b72bbd3f964a52006862de3
# edge name: 4e99dbdfbe7bc875aa42960b
# edge name: 4ce06c1b7e2e236afc128b1b
# edge name: 4bc223d074a9a59359d2d2f6
# edge name: 4da5ec8a4b2280544b678da0
# edge name: 51756c70e4b0182f6ca786f4
# edge name: 504c55e7e4b04421f3310d34
# edge name: 4f69ee04e4b0656e874897dd
# edge name: 4b838dfcf964a520950931e3
# edge name: 512e4182e4b05f7d4843766f
# edge name: 51ac6c98498e44427112f9bf
# edge name: 5155aaffe4b0ea6b60f6a57a
# edge name: 4f15c269e4b03f4c03fb50e0
# edge name: 4f6de0dae4b01489ba002603
# edge name: 4f1a96f2e4b08fa663deae89
# edge name: 4eeb82628b814fef89abbc58
# edge name: 4ed663742c5b3d826ea3dd7d
# edge name: 4bc2c6b374a9a593fbbcd3f6
# edge name: 55a8199d498e61367d215ad2
# edge name: 4d64bf0bb470a14331741dfe
# edge name: 4b6afa55f964a5202fea2be3
# edge name: 5229a4d38bbd9e033d6ef618
# edge name: 511808e6e4b0d096b601a12a
# edge name: 521659d211d2f12183364adf
# edge name: 4f47ce0be4b0c8395ee2c605
# edge name: 4c4be510712ac9284c068a6d
# edge name: 4d6fe31c0187236a34ada2ba
# edge name: 4cd190ef7b685481edc9c7f8
# edge name: 555f6da2498eb806fd973388
# edge name: 4dc2ea4afa7608e86fe52b0d
# edge name: 531e16bd498efd001f4e1e60
# edge name: 4fcf729ae4b07997d3141487
# edge name: 53aea9b6498e1da25de38ae2
# edge name: 4bcc8fa2b6c49c7455f09391
# edge name: 4ccd23f1c0378cfa93b68b48
# edge name: 507c6210e4b076bc192f1072
# edge name: 4f252b1be4b006e5c2e68f30
# edge name: 4cb86ba69552b60cd855cc8b
# edge name: 55c3580e498e110cb64902ed
# edge name: 55a923d5498e3f6acc563a51
# edge name: 548ae2fb498e928ab65ea574
# edge name: 52151be511d28592d8410438
# edge name: 5318cc05498e56c34b1ff045
# edge name: 510a9299e4b0de3a2a1b168c
# edge name: 4f6b3475e4b0b949c4bff64e
# edge name: 4cab502436fa6dcbd0e5d778
# edge name: 4bb78b8f3db7b7139222209a
# edge name: 4ed06c63b8f7971d6aaff4b6
# edge name: 4c0e96c1c6cf76b028fb8051
# edge name: 55d63d73498eeae64dff98b8
# edge name: 4ea3a50430f8b9d5acdf2dfb
# edge name: 4e88b75429c2ea60eefec400
# edge name: 4b82e734f964a52022ec30e3
# edge name: 4bcf4b08b221c9b61dc0d1d0
# edge name: 4f41391be4b0f7b459efed08
# edge name: 50ffb51fe4b0a49395f7f300
# edge name: 50295233e4b0db2acbb75c69
# edge name: 502d7916e4b0648636b82c30
# edge name: 4ecfd1a06c2510ace0371373
# edge name: 558e5ce5498e164a5cb27afc
# edge name: 4f05abfab8f7dcbb400bac99
# edge name: 50b10a19e4b004e6d2ec4344
# edge name: 5042691be4b055ecd356a70e
# edge name: 4d8b488cbc848cfacb8bec2b
# edge name: 4d629fbd865a224b9119c485
# edge name: 4e844af9d3e35a80a8e7ac53
# edge name: 4c601b8490b2c9b6d7013c22
# edge name: 553a0ac0498e07485ab6eb39
# edge name: 4f3566dde4b0d605a55343aa
# edge name: 4c2378557e85c9283495bd21
# edge name: 4f82f949e4b0c7b857825375
# edge name: 509699e9e4b0e52fa47b9ed0
# edge name: 4c798fc193ef236aa517b00f
# edge name: 4f1eb45ee4b0293a86501bdc
# edge name: 4c4c53dbc668e21ee8525afb
# edge name: 4d6174ab73e76a311d0ce196
# edge name: 4fd073eae4b03518ead765e2
# edge name: 526bc398498edc288cd3af17
# edge name: 520533d411d28fa52eae759b
# edge name: 50e1f196e4b0748c84074466
# edge name: 4d9d743a83f36ea82234b894
# edge name: 4e8ab3a3b803fd0aa06a131e
# edge name: 52efd23b11d2203926fb13d2
# edge name: 54d9b9fa498ea38f91e08406
# edge name: 53b710ef498e3c01b54e7248
# edge name: 4c2c9f6ab34ad13aba8cebce
# edge name: 4f0c62ade4b0065899e607da
# edge name: 4efdab659a520dfd643bd750
# edge name: 53de1388498e478b059e1d7d
# edge name: 4e5aba9a1f6e804280d74be3
# edge name: 4cebe55ce1eeb60c48dbb5ae
# edge name: 50ae9bdce4b03c6b1d2395ff
# edge name: 4cf925a14464b60ca97964f8
# edge name: 52c11e7a11d21c6e7f7c0e7b
# edge name: 4e779471d22d80eb34249414
# edge name: 51b22cd0498ef72ef8df784c
# edge name: 4e663c9c7d8b85408b4502ca
# edge name: 5540d43b498eccfc106a61f6
# edge name: 4bea77e6a9900f47f3841640
# edge name: 54bd3160498e8cea0236caff
# edge name: 4c892e4897828cfa5630a2aa
# edge name: 4d1de1b8dd6a236a44642138
# edge name: 4be70e16cf200f47b634153c
# edge name: 4ba6f421f964a5209f7939e3
# edge name: 4ba24acef964a52067ea37e3
# edge name: 506f16bfe4b0eefb57fca019
# edge name: 4ff8433ee4b002d4d3d4992c
# edge name: 514a25f2e4b0b12bdd3b4f96
# edge name: 54b01117498e18b8bcee3f74
# edge name: 4f4a7820e4b07165fb4b3bcb
# edge name: 51816e24498e208c8ca3f1bd
# edge name: 4e6a5492a809290267f633c6
# edge name: 4f58742ae4b0e48a878ebeb7
# edge name: 4eb81e4661af0dda917c47ae
# edge name: 4e7b3595dab41c8304c23e3e
# edge name: 4ead7c5f02d5cf33fa6f9014
# edge name: 4ecbd1a093adb4bd1b56c555
# edge name: 4ec2ba5c775b802d1ff48dbf
# edge name: 51d3194d498ef335e1bdc07f
# edge name: 4e5bcac318388cd5cbc1a9c5
# edge name: 4f744674e4b026e79186b5e4
# edge name: 516df5b9f31cd0ea72e739cb
# edge name: 51e06a2b498ed38b41183bea
# edge name: 54cb6228498ed74155aa6871
# edge name: 54c90c91498e622b8b8e2e70
# edge name: 5106827fe4b0ad7f444202ad
# edge name: 4b8f57b6f964a520025233e3
# edge name: 555c9aa6498e86f0d8a20e2d
# edge name: 4ff3f389e4b05ae522acd704
# edge name: 5139fc8ae4b004aa50c9d237

# %% [markdown]
# Now that we have a populated network, let's plot it! We will use networkx's `draw()` functions.
#
# **Deliverable**
# * You should create a plot of the network. The position of every node (`pos`) should be defined by the lat and lon of the given node. The **color** and **size** of the nodes should be dependent on one of the node properties.

# %%
# Draw the network here
plt.figure(1, figsize=(12,12))

for node in RG.nodes():
    p = nx.get_node_attributes(RG,'pos')
    c = nx.get_node_attributes(RG, 'CHECK-IN')

d = nx.degree(RG)

nx.draw(RG, pos=p, nodelist=d.keys(), node_size=[i * 50 for i in d.values()], \
        node_color=[np.log(j) for j in c.values()], cmap=plt.cm.Blues)

plt.title('Network of Riyadh Transportation Data')

# %% [markdown]
# ## Part 3 - BONUS
# Now that we have the network, it is useful to calculate some of it's properties to gain insights of the region.
#
# First, we will obtain the node degrees, and create a histogram that shows the distribution of the degrees across the network nodes'.
#
# **Deliverable**
# * You should create a histogram showing the degree distribution across the network. The **x-axis** should have the different degrees, and the **y-axis** should have the number of observations.

# %%
# Create your histogram here
d = nx.degree(RG)
degrees = d.values()

plt.figure(2)
plt.hist(degrees,6)
plt.xlabel('Degree')
plt.ylabel('Count')
plt.title('Degree distribution of Riyadh transportation nodes')

# Answer:
# The degree dictionary roughly follows a Poisson distribution.
plt.show()

# %% [markdown]
# Finally, let's look at another useful network property: **centrality**. Centrality indicators help identify the most important vertices within a graph. With centrality algorithms, it is possible to identify key infrastructure nodes in urban networks.
#
# We will be using 2 centrality measures: degree centrality and betweeness centrality. **Betweenness** is a centrality measure of a vertex within a graph. It quantifies the number of times a node acts as a bridge along the shortest path between two other nodes. Conceptually, edges that are more important to the functioning of the network will have a higher betweenness centrality. For `networkx`, the betweenness centrality of a node v is the sum of the fraction of all-pairs shortest paths that pass through v.
#
# Historically first and conceptually simplest centrality measure is **degree centrality**, which is defined as the number of links incident upon a node (the number of ties that a node has). For `networkx`,  the degree centrality for a node v is the fraction of nodes it is connected to.
#
# Using networkx's built-in function, calculate the **degree** and **betweenness** centrality of the network, and create 2 plots of the network, where either the color or the size of the node is dependent on both **centrality** measure.
#
# **Deliverable**
# * You should create a plot of the network. The position of every node (`pos`) should be defined by the lat and lon of the given node. The **color** or **size** of the nodes should be dependent on the centrality measure corresponding to the plot (1 plot for degree, and one for betweenness). The other property not represented by the centrality should depend on another property of the network.

# %%
# Your code here
#Degree centrality
dc = nx.degree_centrality(RG)

plt.figure(3, figsize=(12,12))

for node in RG.nodes():
    p = nx.get_node_attributes(RG,'pos')

nx.draw(RG, pos = p, nodelist=d.keys(), node_size=[i * 50 + 10 for i in d.values()], node_color=[j for j in dc.values()], \
        cmap=plt.cm.Blues)

plt.title('Network of Riyadh Transportation Data, colored by degree centrality')

# %%
#Betweenness centrality
bc = nx.betweenness_centrality(RG)

plt.figure(4, figsize=(12,12))

for node in RG.nodes():
    p = nx.get_node_attributes(RG,'pos')
   
nx.draw(RG, pos = p, nodelist=d.keys(), node_size=[i * 50 for i in d.values()], node_color=[j for j in bc.values()], \
        cmap=plt.cm.Blues)

plt.title('Network of Riyadh Transportation Data, colored by betweenness centrality')
